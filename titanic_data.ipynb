# %% [markdown]
# <a href="https://colab.research.google.com/github/DRA0R/Exploratory_data_analysis/blob/main/titanic_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url='https://raw.githubusercontent.com/terranigmark/curso-analisis-exploratorio-datos-platzi/main/train_titanic.csv'

# %%
titanic_data_set = pd.read_csv(url,error_bad_lines=False)

# %%
titanic_data_set.shape
# Out:
# (891, 12)

# %%
titanic_data_set.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
titanic_data_set.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mujeres=titanic_data_set.loc[titanic_data_set.Sex=='female']['Survived']
tasa_mujeres = sum(mujeres)/len(mujeres)

# %%
hombre=titanic_data_set.loc[titanic_data_set.Sex=='male']['Survived']
tasa_hombres = sum(hombre)/len(hombre)

# %%
titanic_data_set['name_survived'] = titanic_data_set['Survived'].map({0: 'No_survived',
                                  1 : 'survived'})

# %%
fig, ax=plt.subplots(1,2, figsize=(10,8))

titanic_data_set['Sex'].value_counts().plot.bar(color='blue',ax=ax[0])
sns.countplot('Sex', hue='name_survived',data=titanic_data_set, ax=ax[1])   #contar categorias
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.displot(titanic_data_set['Age'].dropna())

# %%
sns.set(style='ticks',color_codes=True)
sns.pairplot(titanic_data_set, vars=['Age','Pclass'], hue= 'name_survived')

# %%
corr_titanic = titanic_data_set.corr(method='pearson')

# %%
sns.heatmap(corr_titanic, annot=True)
